# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = int(input("Enter you salary Amount: "))
service_years = int(input("Enter your service years: "))

if service_years > 5:
    bonus = salary * 0.05
    print("Bonus amount:", bonus)
else:
    print("No bonus")
# Out:
# No bonus

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age : "))

if age > 17:
    print("Your Eligible For Voting")
else:
    print("Your Not Eligible For Voting")
# Out:
# Your Not Eligible For Voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = int(input("Enter number here! "))

if num%2 == 0:
    print(f"{num} is Evern number")
else:
    print(f"{num} is Old number")
# Out:
# 234567890 is Evern number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = int(input("Enter number here! "))

if num%7 == 0:
    print(f"{num} is Divisible by 7")
else:
    print(f"{num} is Not Divisible by 7")
# Out:
# 45 is Not Divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = int(input("Enter number here! "))

if num%5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Bye

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
num =int(input("Enter a Number "))

print(num%10)
# Out:
# 0

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input("Enter the Length of the rectangle!"))
breadth = int(input("Enter the Breath of the rectangle!"))

if length == breadth :
    print("square")
else:
    print("rectangle")
# Out:
# rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
num1 = int(input("Enter the first No"))
num2 = int(input("Enter the Second No"))

if num1 > num2:
    print(f"{num1} is Greater than {num2}")
else:
    print(f"{num2} is Greater than {num1}")
# Out:
# 45 is Greater than 4

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
cost = 100
dis = 10/100
Q = int(input("Enter the Quantity what you want! "))
t_cost = cost * Q

if t_cost > 1000:
    dis_p = t_cost * dis 
    amount = t_cost - dis_p
    print(amount)
else:
    print(t_cost)
# Out:
# 990.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("Enter the marks"))

if marks >= 80 and marks <100:
    print("A Gradde")
elif marks >= 60 and marks <80:
    print("B Grade")
elif marks >= 50 and marks <60:
    print("C Grade")
elif marks >= 45 and marks <50:
    print("D Grade")
elif marks >= 25 and marks <45:
    print("E Grade")
elif marks <25 and marks >= 0:
    print("F Grade")
else:
    print("Enter the marks between 0 - 100")
# Out:
# Enter the marks between 0 - 100

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
class_held = int(input("Enter the Number of classes Held"))
attendence = int(input("Enter the Number of classes you Attendeds"))

p = attendence / class_held * 100

if p >= 75:
    print(" You will be allowed to sit in exam")
else:
    print("Your attendence it Less than 75% \n so will not allowed to sit in exam ")
# Out:
# Your attendence it Less than 75%
#  so will not allowed to sit in exam

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
class_held = int(input("Enter the Number of classes Held"))
attendence = int(input("Enter the Number of classes you Attendeds"))

p = attendence / class_held * 100

if p >= 75:
    print(" You will be allowed to sit in exam")
else:
    med = input("if you had medical problem  or not Enter Y or N  ")

    if med.lower() == "y":
            print(" You will be allowed to sit in exam")
    else:
     print("Your attendence it Less than 75% \n so will not allowed to sit in exam ")
# Out:
#  You will be allowed to sit in exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter a Year"))

if year%400 == 0:
            print(f" {year} is Leap Year")
elif year%100 == 0:
   print(f" {year} is Not Leap Year")
elif year%4 ==0:
       print(f"{year} is a leap Year")
    
else:
     print(f"{year} is not a leap year")
# Out:
# 2024 is a leap Year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Enter age: "))
gender = input("Enter gender (M/F): ")
marital = input("Enter marital status (Y/N): ")

if gender == "F":
    print("Work only in urban areas")

elif gender == "M" and 20 <= age <= 40:
    print("Work anywhere")

elif gender == "M" and 40 < age <= 60:
    print("Work only in urban areas")

else:
    print("ERROR")
# Out:
# Work only in urban areas

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
units = int(input("Enter You bill Units :"))
if units >= 200:
    print(f"your bill amount is : {units * 10}")
elif units >= 100:
    print(f"Your bill amount is : {units * 5}")
else:
    print(f"Your bill amount is : {units * 0} ")
# Out:
# Your bill amount is : 0

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1 = int(input("Enter age of person 1: "))
age2 = int(input("Enter age of person 2: "))
age3 = int(input("Enter age of person 3: "))

if age1 > age2 and age1 > age3:
    print("Person 1 is oldest")
elif age2 > age1 and age2 > age3:
    print("Person 2 is oldest")
else:
    print("Person 3 is oldest")

if age1 < age2 and age1 < age3:
    print("Person 1 is youngest")
elif age2 < age1 and age2 < age3:
    print("Person 2 is youngest")
else:
    print("Person 3 is youngest")
# Out:
# Person 3 is oldest
# Person 2 is youngest
